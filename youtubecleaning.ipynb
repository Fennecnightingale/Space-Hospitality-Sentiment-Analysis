# %%
import pandas as pd 
import numpy as np 
from datetime import datetime
import nltk
from nltk.tokenize import word_tokenize
import csv
import re

# %%
pd.set_option('display.max_columns', 10000)
pd.set_option('display.max_rows', 10000)

# %%
# found on stackoverflow @ https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

# %%
def reset(df):
    """
    pass in dataframe and returns dataframe with index reset
    just wanted to make it a bit of a quicker type since I'm using it so much 
    """
    return df.reset_index(drop=True, inplace=True)

def remove_comments(df, column, list_to_remove):
    """
    Pass in your dataframe, a column & a list of words to search for and remove.
    Does not change capitalization, but will remove if word is within another word.
    Returns dataframe with words removed. 
    """
    for item in list_to_remove:
        reset(df)
        for i in range(len(df)):
            if type(df.at[i, column]) == str:
                if item in df.at[i, column].lower():
                    df.drop(index=i, inplace=True)
    return df

# %%
df = pd.read_csv('data/3.29.youtube.csv')

# %%
df = df[[ 'video_id', 'text', 'likes', 'date',
       'channel_id', 'viewer_rating', 'mentions', 'comment_id']].copy()

# %%
# getting rid of duplicate entries (if any)
df = df.drop_duplicates(subset='comment_id')
df = df.reset_index(drop=True)

# %%
# converting our date column to a column of datetime objects 
for row in range(len(df)):
    df.at[row, 'date'] = datetime.strptime(df.at[row, 'date'].replace('T', ' ').replace('Z','')[2:], '%y-%m-%d %H:%M:%S')

# %%
df = df.drop('viewer_rating', 1)

# %%
df.dropna(axis=0, subset=['text'], inplace=True)

# %%
df.reset_index(inplace=True)

# %%
text = ['elmer', 'fudd', 'impediment', 'mawrs', 'retard', 'voiceover', 'lisp', 'studder', 'accent', 
        'antichrist', 'sjw', 'dwopping', 'arthursday', 'bitch', 'junior high', 'shout out', 'shoutout', 
        'acadamy', 'middle school', 'high school', 'secondary school', 'academy']

# %%
df = remove_comments(df, 'text', text)

# %%
def clean_string(string):
    for symbol in "'’":
        string = string.replace(symbol, '')
    for symbol in "`@#()[]{}<>;_-=+~:,.?!''\n^\/“$":
        string = string.replace(symbol, ' ').lower()
    string = string.replace('"', ' ')
    string = string.replace('&', 'and')
    string = deEmojify(string)
    encoded_string = string.encode("ascii", "ignore")
    decode_string = encoded_string.decode()
    return decode_string

reset(df)
for i in range(len(df)):
    df.at[i, 'text'] = clean_string(str(df.at[i, 'text']))

# %%
for item in ['hello', 'hi', 'first comment']:
    reset(df)
    for i in range(len(df)):
        if type(df.at[i, 'text']) == str:
            if item in df.at[i, 'text']:
                if len(df.at[i, 'text']) < len(item) + 10: # too short to be anything but a greeting to the author
                    df.drop(index=i, inplace=True)

# %%
reset(df)
one_big_list = []

for i in range(len(df)):
    for word in word_tokenize(str(df.at[i, 'text'])):
        for symbol in "'[],":
            word = word.replace(symbol, "")
        if word != '':
            if word.startswith('//') != True:
                if word.startswith('http') != True:
                    one_big_list.append(word)

# %%
def count_vectorize(text):
    unique_words = set(text)
    word_dict = {i:0 for i in unique_words}
    
    for word in text:
        word_dict[word] += 1
    
    return word_dict

vectorized = count_vectorize(one_big_list)

# %%
a_file = open("data/vect_yts.csv", "w", encoding="utf-8")

writer = csv.writer(a_file)
for key, value in vectorized.items():
    writer.writerow([key, value])

a_file.close()

# %%
new_df = pd.read_csv('data/vect_yts.csv')

# %%
add_df = pd.DataFrame(columns=['word', 'count'], index=range(1))
add_df.at[0, 'word'] = new_df.columns[0]
add_df.at[0, 'count'] = new_df.columns[1]

# %%
new_df = new_df.rename(columns={new_df.columns[0]:'word', new_df.columns[1]:'count'})
new_df = new_df.append(add_df)

# %%
new_df['count'] = new_df['count'].astype(int)
new_df = new_df.sort_values('count', ascending=False)

# %%
new_df.to_csv('data/count_yts')

# %%
df = df[['text', 'likes', 'channel_id', 'mentions', 'comment_id']]
df = df.rename(columns={'likes':'favorite_count', 'channel_id':'user_id', 'post_id':'comment_id'})

# %%
df['repost_count'] = 0

# %%
text_counts = df['text'].value_counts().to_frame().reset_index().rename(columns={'index':'text', 'text':'count'})

# %%
for i in range(len(df)):
    df.at[i, 'repost_count'] = text_counts.loc[text_counts['text'] == df.at[i, 'text']]['count']

# %%
df.to_csv('data/cleaned_comments.csv')

# %%
df['repost_count'] = df['repost_count'] - 1

# %%
reset(df)
for i in range(len(df)):
    if len(df.at[i, 'text']) <= 6:
        df.drop(index=i, inplace=True)

# %%
# df.drop_duplicates(subset='text').sort_values(by='repost_count', ascending=False).head(100)
# Out:
#                                                      text  favorite_count  \
# 85320                               what about wormholes              0.0
# 2996                                              thanks              0.0
# 131524                   davis elementary school georgia              0.0
# 131450       st  cyril school in calgary  alberta  canada             2.0
# 1815                                              amazing             0.0
# 131507                        kent denver school colorado             0.0
# 4954                                         great video              1.0
# 130243  bismarck henning jr high in bismark  il  go ea...             0.0
# 131322  buckeye jhs in medina ohio we love to watch cn...             0.0
# 1195                                           thank you              0.0
# 130189  bismarck henning  jr in bismarck il go eagles                 0.0
# 787                                              awesome              0.0
# 5290                                          great video             1.0
# 5882                                      happy birthday              2.0
# 56831                        https   youtu be eay 0b6vgks             0.0
# 84637                                          wormholes              1.0
# 10789                                             awesome             1.0
# 131609                   tully elementary school tully ny             0.0
# 130643  five keys school in redwood city  ca\r \r we h...             0.0
# 1743                                              agreed              2.0
# 34331                                           thank you             0.0
# 130215  pilgrim school 5th grade kollers class   in l ...             0.0
# 120463            johnson brock public school johnson  ne             0.0
# 997                                              amazing              0.0
# 130603  east cobb middle mareietta georgia we love you...             0.0
# 10650                                         sign me up              1.0
# 43109                                           beautiful             0.0
# 131431        st cyril school in calgary  alberta  canada             0.0
# 10354                                             exactly             0.0
# 130297                                          go titans             0.0
# 82823       1   5   8   0    9   5   2  4   2  5  7 wsapp             0.0
# 6975                                          occupyvenus             0.0
# 17755                                                                 0.0
# 131359  scootny springs othello washington home of the...             0.0
# 1295                                                                  0.0
# 130316                          cass midway from missouri             0.0
# 86413                                what about wormholes             0.0
# 86437                              what about worm holes              0.0
# 84772                                           wormholes             0.0
# 17378                                            exactly              1.0
# 130403                    thanks now i know where u live              0.0
# 224     UCx7dgNEedjiyd9DPP_stKMw  UgxmlQwS0az3oDxZnPZ4AaABAg
# 2614    UCVn7fAjWcpEP8nZqaEy6W2A  Ugw1TpjrTfGGiebiQm94AaABAg
# 8410    UC_DWaKtBmDFqfeNl8k1sKLA                         NaN
# 1197    UCgczhVpc-7rq86bSli_sOCA                         NaN
# 19263   UCkGPdy6kn6mcPhxe1jlnn1g  Ugzs3LMaZ3DC4dtPICd4AaABAg
# 131426  UCWvaWAlFHyUXXMTdctDGxEg                         NaN
# 57994   UCvOQOnCsLtuVQP61S72l8uA                         NaN
# 131659  UCurMs34orw46hJ_i9veMlvw                         NaN
# 10114   UCzFpf8ve9oJf9DaBrAf4TfQ                         NaN
# 18411   UCPMIO3Ah_wqOa0RhmrKhHfA  UgxjXL3IeQ0o1zfirqV4AaABAg
# 121526  UCmsciwbcogB1arOG3bTI8QQ                         NaN
# 21675   UCM3PiGoDVrTKAeve2p8rLaQ  UgyvkZODCmubXfoGtnd4AaABAg
# 28819   UCUGroYXurfCsiD-WBmkEE6w                         NaN
# 82824   UCVdt3Ac_vrSF6YCLxgTlFtg  Ugyu1xD2Vt97pNnKuwh4AaABAg
# 88690   UCZfwM9VG8r-le6_5RgLi4rg                         NaN
# 130654  UCXA-zP9OLpLt69CmRGiTIBw                         NaN
# 18237   UCgTO5ppxuSzufiwrC7NN6aw                         NaN
# 131066  UCMsg5YgGhMwAAlsA5GUZf0A                         NaN
# 18410   UCPMIO3Ah_wqOa0RhmrKhHfA  UgxjXL3IeQ0o1zfirqV4AaABAg
# 85001   UCMqIvkBRPY7__feosJEKxwA                         NaN
# 90462   UCHBHnnXcr8eghtvB7xa1Oow                         NaN
# 21420   UCpcMT4aSEcWoS8Lle8i_SVA                         NaN
# 3098    UC6Qd84r-9iUa7yU0c7dcAAg                         NaN
# 84992   UC61vF7BrjubL2R5QIxJ2fBA                         NaN
# 130555  UCl1H4NIqPQhfgu9N9o3a-MA                         NaN
# 78009   UCFIu-XrTDHftJCYMGb43yXg  Ugw5Eflm_5rMoCnx5CJ4AaABAg
# 7155    UCuzQUsejZJJkTlbeqMH4-Kw  Ugxae8Y7qxYYIE3ZgOd4AaABAg
# 59185   UCeKCvaqjXbF04E0znX7-HnQ                         NaN
# 85065   UC61vF7BrjubL2R5QIxJ2fBA                         NaN
# 130148  UC30zBzLCgGjIcSdbYgZiOcg                         NaN
# 43505   UCdje7uOpagAmPwkyaOZZeQw                         NaN
# 8136    UCfP1-oqkhtGVTuOuCo80blw                         NaN
# 6873    UCHVOpB-jYDvgG21pCDi6h8g                         NaN
# 130847  UCvZhuJeoROjsOBcACIl8PQA                         NaN
# 131400  UCviAIzsSoLM16NUIHeecbgQ                         NaN
# 50073   UCF-7zZjXBus5GjGxGevJj4A                         NaN
# 2374    UC0WnH4KT25yEQ0LNiKTD0eQ  Ugz6g17ANLjILHZ5Kc94AaABAg
# 98474   UC9cydesWzv8lVQh3us0fSWA                         NaN
# 131375  UChQTExurEkZDwv3o3mxkGqw                         NaN
# 25755   UClTnciFSV7--CGERp0BgIbA                         NaN
# 130467  UC2ZwxleC1z1JVUR63taIktQ                         NaN
# 18657   UC4LDfaF1wN6YthXfT6aYLSw  UgzsuQ-N2PbahQYMxY94AaABAg
# 42375   UCr-KNfgYXS-vsNnoABsVrtA                         NaN
# 66951   UCvPBwFtlth679NMXM2jsxlg  Ugy6lj--CSPTSrA0ELZ4AaABAg
# 828     UCAUoyOZdD9EKsgB0H-GCZcA  UgyJ5MOyLAv1yP4nxtR4AaABAg
# 131283  UCn-MVvr7a1HIkGQi72hvmIQ                         NaN
# 140630  UC8nKqo2NebypV2MaSny8Q6g                         NaN
# 84993   UC61vF7BrjubL2R5QIxJ2fBA                         NaN
# 23130   UCzONpoVikqdhxxTUJ2eCvow  UgxivzlZzuWNuRWrzCd4AaABAg
# 130289  UC5DKMT-MrTWjb4tD1yrCODg                         NaN
# 94454   UCPtVUcK9nqndQpZFvNYt9kg                         NaN
# 48726   UCgiQe-U7c46ruvy72wu7DZA                         NaN
# 16734   UCeXAKqG0CpIE1ss3VqXKrhg  UgzY-cQxnFLwysq3K8x4AaABAg
#
#                                                comment_id  repost_count
# 85320                          UgxJc68bfZ0m4JDkIbl4AaABAg            62
# 2996          UggssEFpGrmi2HgCoAEC.8RDg_or5LiI8REero1P_bD            47
# 131524                         Ugxjh7pwXZ0IHdikBLF4AaABAg            43
# 131450                         Ugz-J2XbYnFHRy0bBcF4AaABAg            40
# 1815                           Ugxa9usRdYbS02SE7v94AaABAg            38
# 131507                         Ugz4iIfTbqtThR6cjWB4AaABAg            34
# 4954                           UgxvbFtMzwEI5dleB8t4AaABAg            34
# 130243                         UgyR8Tng1u8rUXeexuZ4AaABAg            33
# 131322                         UgzNx_PhtDILvnhWf6N4AaABAg            27
# 1195    UgxVggWjoRFuXByoD-t4AaABAg.9GiI1V5pAlF9HwlKuX1Z2R            25
# 130189                         UgwByqK08ecMgrRd87V4AaABAg            25
# 787                            UgyDVu4BSIlduwLzyoJ4AaABAg            24
# 5290                           UgyeracgNYwBWb1STrV4AaABAg            23
# 5882    UgwNog6uEMWiWoWG63x4AaABAg.8_Ji4MdN-9z8_JnyBgfPA4            22
# 56831   Ugw4zoEbR6OyAiF4EeF4AaABAg.9E52XPB1CKL9E54mAjyB1y            20
# 84637                          Ugz-Gx3zgR6kEOLcVDB4AaABAg            19
# 10789                                UggL8nhPzRaZeHgCoAEC            19
# 131609                         Ugzw-Ep9WSU2KzWTOIZ4AaABAg            19
# 130643                         UgyzppRG2QMQqzKw1Wh4AaABAg            18
# 1743    UgwJ5gkGTINU0ppyX1Z4AaABAg.9GHkET1CXZ89GjW2ngF_Z9            17
# 34331                          UgyKrjkCJw4Ncvu2pWB4AaABAg            17
# 130215                         UgxevnYhks1VJhFoout4AaABAg            17
# 120463                         Ugwa5WtpXZjD3nCNLeZ4AaABAg            17
# 997                            Ugx6m7Xb0BivqjLuxLt4AaABAg            16
# 130603                         UgwJB2Mdc4bqPx2Dh6B4AaABAg            16
# 10650                                UgizQKBOUYrnhngCoAEC            15
# 43109                          UgyuvFDGLuYy_6emuvF4AaABAg            15
# 131431                         UgxGXD2VI7IFmEdOm8N4AaABAg            14
# 10354   UgxY21VrT1X-PySaR5B4AaABAg.8bKhJJrZpXj8dfmSXO2dvU            14
# 130297                         UgwQTLxFIH_q4j_-pB54AaABAg            14
# 82823   Ugyu1xD2Vt97pNnKuwh4AaABAg.9KPVkD-bGTu9KPdVSBf9sL            13
# 6975                           UgzIjUB9hSyJwYmVwKl4AaABAg            13
# 17755   Ugyj7AJHHm9gMXNTUZ94AaABAg.9DryCPGjSXb9DsBYCtPWZ8            13
# 131359                         UgwRurRAvwh879mk6MZ4AaABAg            13
# 1295                           UgxEddj9PkV_GCdZxo94AaABAg            13
# 130316                         UgzobxZWp0oiqe2rMxF4AaABAg            13
# 86413                          UgwxtUuTblI7w_mbCVx4AaABAg            13
# 86437                          UgzQECQW3f1exG6TiQp4AaABAg            13
# 84772                          UgxFGmMPW2mtQrN6ku14AaABAg            12
# 17378   Ugx77oAsLVm3UrM4mvp4AaABAg.9EbmAknWx5_9JHrd8uY2vx            12
# 130403  UgwtQW01CFSDp79LZCV4AaABAg.9Kl37HsGRYf9Kl3Eo_gJF1            12
# 22263                          UgwoA0vGX8RBjlz2S2R4AaABAg            12
# 130808                         Ugx8kCIxYpjzO0p08R94AaABAg            11
# 1590                           UgyHRJ1yY17kbkW5dhh4AaABAg            11
# 29176                          Ugyj_XefpTHcCXZp6Bh4AaABAg            11
# 2225    UgwmKMrG6PceOC3iEQ14AaABAg.9GGZTaiEqWh9GG_QQGJL1H            11
# 19485   UgyZ_QJVardXu64yDXt4AaABAg.99wk5Sx2LPE9BVukFcJ7kK            11
# 224     UgxmlQwS0az3oDxZnPZ4AaABAg.9GGva76RqIV9GHuYikX6u3            10
# 2614    Ugw1TpjrTfGGiebiQm94AaABAg.9GGV__LUci_9Gcy5e_A_uw            10
# 8410                           UgwFA4vejxK9dYBTX754AaABAg            10
# 1197                           UgyAFordTN5F_IGbf3R4AaABAg            10
# 19263   Ugzs3LMaZ3DC4dtPICd4AaABAg.9A8aQPJ8UnN9CwidM_4X6f            10
# 131426                         UgydM-Z95AUe6HClBuR4AaABAg            10
# 57994                          UgzhuTqePX_JZ-s_71p4AaABAg            10
# 131659                         UgyjZ8HYRJhxMi482R14AaABAg            10
# 10114                          Ugx_6-zHzK7N8d0mOtx4AaABAg            10
# 18411   UgxjXL3IeQ0o1zfirqV4AaABAg.9C5LHga-gtQ9GE31rIxKb8            10
# 121526                         Ugw7MPAHJB1shkMq4b14AaABAg             9
# 21675   UgyvkZODCmubXfoGtnd4AaABAg.92wE9uRcunt98lnT-BhgkJ             9
# 28819                          UgwixZsDmzLIrxISQIZ4AaABAg             9
# 82824   Ugyu1xD2Vt97pNnKuwh4AaABAg.9KPVkD-bGTu9KPdSypJ5ko             9
# 88690                          UgwJnHvFaYoDnvSJSCp4AaABAg             9
# 130654                         UgwcSrzZqNWTIdf4SvR4AaABAg             9
# 18237                          Ugw9d_iJdF0UA71K1xV4AaABAg             9
# 131066                         UgwPP-sC2BQgHsHT5Nt4AaABAg             9
# 18410   UgxjXL3IeQ0o1zfirqV4AaABAg.9C5LHga-gtQ9GE32ggqGOM             9
# 85001                          UgwOwJ0Sh8rhT8tay894AaABAg             9
# 90462                          UgxbcmEvLU_bVs31d1V4AaABAg             9
# 21420                          UgwZUfe78b1_eSHZFDR4AaABAg             8
# 3098                                 Uggs2Pa36xVzmHgCoAEC             8
# 84992                          Ugy2FrX0xRtKDcjfNDR4AaABAg             8
# 130555                         Ugx-84jm3vcidfdJQJx4AaABAg             8
# 78009   Ugw5Eflm_5rMoCnx5CJ4AaABAg.8ny6EtggMdS8o-72_vMpfV             8
# 7155    Ugxae8Y7qxYYIE3ZgOd4AaABAg.8WNsYlODxNu8Yj1MH6PT9k             8
# 59185                          Ugzuy0uCdeNuFdMGXeV4AaABAg             8
# 85065                          UgyLK8OLsSAgnm9NKe14AaABAg             8
# 130148                         UgzhDNRGwtDqS9vSGMZ4AaABAg             8
# 43505                          Ugy5GsNnjxAb7bUhixZ4AaABAg             8
# 8136                           UgyAsDSaBZTnv7AMj-Z4AaABAg             8
# 6873                           UgwRLezJAEqsL-wVAfZ4AaABAg             8
# 130847                         UgxcDZdz10do6XaCKQJ4AaABAg             7
# 131400                         Ugz0I3hY08bDISrWN714AaABAg             7
# 50073                          Ugyq6rg21dYB1xO7Uxd4AaABAg             7
# 2374    Ugz6g17ANLjILHZ5Kc94AaABAg.9GGWh4MsnC59GGZEbP94So             7
# 98474                          UgxKWw7fvN9iwVsZMh94AaABAg             7
# 131375                         UgzivPME0Y3K_dbP4614AaABAg             7
# 25755                          UgxWDFpu45zkrEponld4AaABAg             7
# 130467                         Ugw7ZgkKSD17TKHkW4p4AaABAg             7
# 18657   UgzsuQ-N2PbahQYMxY94AaABAg.9Bgh1Vn9C3U9FuEic8LKmr             7
# 42375                          UgyCzw8BJ4V5QS2rOoZ4AaABAg             7
# 66951   Ugy6lj--CSPTSrA0ELZ4AaABAg.8etI_ciOba38etknIe4Snu             7
# 828     UgyJ5MOyLAv1yP4nxtR4AaABAg.9HUCE2rF8gl9IkIRKHhyOu             7
# 131283                         Ugw5XP6dWDC71wUd6aB4AaABAg             7
# 140630                         UgwKe_rED5NsaJLrA5J4AaABAg             6
# 84993                          Ugwkdfe2oBWyevy_5E94AaABAg             6
# 23130   UgxivzlZzuWNuRWrzCd4AaABAg.8zq4iXaDQ5j91CoGDC5z30             6
# 130289                         UgyIZ60IHkq62FkzGL54AaABAg             6
# 94454                          UgwZyqtPaxJlHoAyPCt4AaABAg             6
# 48726                          UgxuNt4qn2wTk4VYxip4AaABAg             6
# 16734   UgzY-cQxnFLwysq3K8x4AaABAg.9Gk1HVvn3AE9GmLuQ1tZT6             6

# %%
#91732
#3609024337 l&i check reissuing phone num
