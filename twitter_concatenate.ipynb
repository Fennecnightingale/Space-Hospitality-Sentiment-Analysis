# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('tweets_march08.csv')
df2 = pd.read_csv('tweets_march10.csv')
df3 = pd.read_csv('tweets_march16.csv')
df4 = pd.read_csv('tweets_march17.csv')
df5 = pd.read_csv('tweets_march18.csv')
df6 = pd.read_csv('tweets_march28.csv')
df_fen = pd.read_csv('3.26.twitter')
# Out:
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (0,1,2,3,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#   Unnamed: 0 Unnamed: 1  favorite_count hashtag  \
# 0          0        NaN             0.0
# 1          1        NaN             0.0
# 2          2        NaN             0.0
# 3          3        NaN             0.0
# 4          4        NaN             0.0
#
#                          mentions       post_id  retweet_count symbols  \
# 0    951062029 750389033579184129  1.368697e+18          118.0      []
# 1    951062029 750389033579184129  1.368695e+18          118.0      []
# 2    951062029 750389033579184129  1.368691e+18          118.0      []
# 3                                  1.368689e+18            0.0      []
# 4    951062029 750389033579184129  1.368686e+18          118.0      []
#
#                                                 text             user  \
# 0  RT @MichaelGalanin: A collection of spectacula...        trikinho1
# 1  RT @MichaelGalanin: A collection of spectacula...    dudiiskandar5
# 2  RT @MichaelGalanin: A collection of spectacula...  pN31GQUxrDoUKe6
# ...

# %%
df1.drop(['Unnamed: 0', 'Unnamed: 1'], axis=1, inplace=True)

# %%
df2.head()
# Out:
#   Unnamed: 0 favorite_count hashtag  \
# 0          0            0.0     NaN
# 1          3            0.0     NaN
# 2         10            2.0     NaN
# 3         13            2.0     NaN
# 4         20            1.0     NaN
#
#                                             mentions       post_id  \
# 0                       951062029 750389033579184129  1.368697e+18
# 1                                                NaN  1.368689e+18
# 2                                                NaN  1.368670e+18
# 3                                                NaN  1.368657e+18
# 4    1315900032365793281 750389033579184129 36851...  1.368645e+18
#
#    retweet_count symbols                                               text  \
# 0          118.0     NaN  RT @MichaelGalanin: A collection of spectacula...
# 1            0.0     NaN    ExoMars goes for a spin https://t.co/lsZkrvNmo6
# 2            0.0     NaN  New session: Perseverance ⟷ ExoMars TGO\nExpec...
# ...

# %%
df2.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#    Unnamed: 0  index  Unnamed: 2  favorite_count  \
# 0           0      0         NaN             0.0
# 1           1      1         NaN             0.0
# 2           2      2         NaN             0.0
# 3           3      3         NaN             0.0
# 4           4      4         NaN             0.0
#
#                                 hashtag               mentions       post_id  \
# 0    TechmashUK StellarisConsoleEdition    178671032 178671032  1.371422e+18
# 1    TechmashUK StellarisConsoleEdition    178671032 178671032  1.371422e+18
# 2    TechmashUK StellarisConsoleEdition              178671032  1.371422e+18
# 3    TechmashUK StellarisConsoleEdition    178671032 178671032  1.371417e+18
# 4    TechmashUK StellarisConsoleEdition    178671032 178671032  1.371417e+18
#
#    retweet_count symbols                                               text  \
# 0            2.0      []  RT @TechMASHUK: Nemesis comes to the Stellaris...
# ...

# %%
df3.drop(['Unnamed: 0', 'index', 'Unnamed: 2'], axis=1, inplace=True)

# %%
df4.head()
# Out:
#    Unnamed: 0  index  Unnamed: 2  favorite_count                  hashtag  \
# 0           0      0         NaN             0.0
# 1           1      1         NaN             0.0                      KAI
# 2           2      2         NaN             0.0                      EXO
# 3           3      3         NaN             0.0
# 4           4      4         NaN             0.0    SUHO StanWorld 수호 EXO
#
#                                             mentions       post_id  \
# 0                                1318175737627570176  1.372029e+18
# 1                                         2368697754  1.372029e+18
# 2             1184793275271503872 873115441303924736  1.372029e+18
# 3                                 873115441303924736  1.372029e+18
# 4    1353321720468303873 1210816204023033856 1337...  1.372029e+18
#
#    retweet_count symbols                                               text  \
# 0            0.0      []  @milkyslyth 🎫SELL TICKET BUBBLE SM JYP🎫\n\nEXO...
# ...

# %%
df4.drop(['Unnamed: 0', 'index', 'Unnamed: 2'], axis=1, inplace=True)

# %%
df5.head()
# Out:
#   Unnamed: 0 favorite_count        hashtag                          mentions  \
# 0          0            1.0            NaN               1055046181397635072
# 1          1            0.0        ExoMars             4823641894 3685103662
# 2          2            0.0        ExoMars    4823641894 3685103662 21436960
# 3          3            0.0    OTD ExoMars                        2317370365
# 4          4            4.0            NaN                               NaN
#
#         post_id  retweet_count  \
# 0  1.372308e+18            0.0
# 1  1.372231e+18            4.0
# 2  1.372231e+18           18.0
# 3  1.372191e+18           30.0
# 4  1.372184e+18            0.0
#
#                                                 text             user  \
# 0  @WebKarls We want third Martian rover, the one...      GCC_Cosplay
# 1  RT @Thales_Alenia_S: Happy birthday to our bel...       LukaszKort
# 2  RT @Thales_Alenia_S: Happy birthday @ESA_TGO! ...       LukaszKort
# ...

# %%
df5.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df6.head()
# Out:
#    Unnamed: 0  favorite_count   hashtag  \
# 0           0             0.0       NaN
# 1           1             0.0       NaN
# 2           2             0.0    EXO 엑소
# 3           3             0.0    EXO 엑소
# 4           4             0.0       NaN
#
#                                   mentions       post_id  retweet_count  \
# 0                      1159620315107844097  1.375800e+18         3527.0
# 1                               1647438986  1.375800e+18          159.0
# 2    894043137877852160 873115441303924736  1.375800e+18           12.0
# 3    967767641040433152 873115441303924736  1.375800e+18         2265.0
# 4                                337562055  1.375800e+18         2198.0
#
#                                                 text             user  \
# 0  RT @no_loey_no_life: EXO'S special appearance ...          hanshyl
# 1  RT @_xiuweetheart: I’m so happy to see that mo...      mimibear112
# 2  RT @exomutualgain: follow everyone who likes t...  BvlgariCotton91
# ...

# %%
df6.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# ATTEMPTING CONCATENATING
# dfList = [df1, df2, df3, df4, df5]  
# master_twitter_df = pd.concat(dfList)

# %%
df_fen.head()
# Out:
#    Unnamed: 0            user       user_id  \
# 0           0          SpaceX  3.474325e+07
# 1           1        elonmusk  4.419640e+07
# 2           2       BenMeer20  4.860371e+08
# 3           3  Erdayastronaut  3.167257e+09
# 4           4          SpaceX  3.474325e+07
#
#                                                 text  favorite_count symbols  \
# 0  deployment of 60 starlink satellites confirmed...         97534.0      []
# 1   sn11 almost ready to fly https://t.co/fxmjjzoikk         60997.0      []
# 2  hardest jobs in the universe:\n\n1: brain surg...         44289.0      []
# 3  honestly, if i hadn’t seen this with my own ey...         40107.0      []
# 4  deployment of 60 starlink satellites confirmed...         39910.0      []
#
#    retweet_count mentions hashtag       post_id
# 0         9272.0      NaN     NaN  1.367407e+18
# 1         4389.0      NaN     NaN  1.371995e+18
# 2         3939.0      NaN     NaN  1.368354e+18
# ...

# %%
df_fen.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
cols = df_fen.columns.tolist()
cols
# Out:
# ['user',
#  'user_id',
#  'text',
#  'favorite_count',
#  'symbols',
#  'retweet_count',
#  'mentions',
#  'hashtag',
#  'post_id']

# %%
cols = [cols[3], cols[-2],  cols[-3], cols[-1], cols[-4], cols[4], cols[2], cols[0], cols[1]]

# %%
df_fen = df_fen[cols]

# %%
df_master = df1.append([df2, df3, df4, df5, df6, df_fen])
# Out:
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
len(df_master)
# Out:
# 1633736

# %%
df_master.drop_duplicates(subset='post_id', inplace=True)

# %%
len(df_master)
# Out:
# 1078491

# %%
# convert to .csv file
df_master.to_csv(r'master_tweets.csv')
