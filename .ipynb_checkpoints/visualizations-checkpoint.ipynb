# %%
# !pip install twython
# !pip install apscheduler
# Out:
# Collecting twython
#   Downloading twython-3.8.2-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests>=2.1.0 in /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from twython) (2.24.0)
# Collecting requests-oauthlib>=0.4.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests>=2.1.0->twython) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests>=2.1.0->twython) (2020.12.5)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 18.3 MB/s eta 0:00:01     |█████████████████████████████   | 133 kB 18.3 MB/s eta 0:00:01
# Installing collected packages: oauthlib, requests-oauthlib, twython
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 twython-3.8.2

# %%
import os
import datetime
import json
import twython
import json

# %%
import pandas as pd
import numpy as np

# %%
from twython import Twython
from contextlib import suppress
from requests_oauthlib import OAuth1Session
from apscheduler.schedulers.background import BackgroundScheduler as Scheduler

# %%
# Load credentials from json file
with open("/Users/tlipman/.secret/twitter_credentials.json", "r") as file:
    creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# %%
# getting the header for our dataframe so we have something to append to 
startdf = pd.read_csv('df')
# when our dataframe is created the index is unnamed, when you export it is renamed so we need to fix it so our df realizes it's the same 
startdf = startdf.head(0).rename(columns={'Unnamed: 0':''})
#assign our id as the most recent tweet id to start so that we get everything after it 
id_ = python_tweets.search(**{'q': 'RT', 'result_type': 'recent', 'count': 2})['statuses'][0]['id']

def myfn(q, name):
    # import global variables we will be using this function to alter
    global id_
    global startdf 
    # Create our query
    query = {'q': q,
            'result_type': 'recent',
            'count': 100,
            'lang': 'en',
            'max_id': id_,
            'entities': {
                "hashtags": [],
                "symbols": [],
                "user_mentions": []
            }
            }
    #build our query into a dictionary to easily turn into dataframe 
    dict_ = {'user': [], 'user_id':[], 'post_id': [], 'text': [], 'favorite_count': [], 'hashtags':[], 'symbols':[], 'user_mentions':[], 
             'retweet_count':[]}
    for status in python_tweets.search(**query)['statuses']:
        dict_['user'].append(status['user']['screen_name'])
        dict_['user_id'].append(status['user']['id'])
        dict_['text'].append(status['text'])
        dict_['hashtags'].append(status['entities']['hashtags'])
        dict_['symbols'].append(status['entities']['symbols'])
        dict_['user_mentions'].append(status['entities']['user_mentions'])
        dict_['favorite_count'].append(status['favorite_count'])
        dict_['retweet_count'].append(status['retweet_count'])
        dict_['post_id'].append(status['id'])
    # put data in a DataFrame to work with it easier
    df = pd.DataFrame(dict_)
    #removing our vairables stuck in dictionaries within our dataframe and give them their own columns
    df['mentions'] = ' '
    df['hashtag'] = ' '
    for i in range(len(df)):
        for j in range(len(df.at[i, 'user_mentions'])):
            try:
                df.at[i, 'mentions'] = str(df.at[i, 'mentions']) + ' ' + str(df.at[i, 'user_mentions'][j]['id'])
            except:
                df.at[i, 'mentions'] = str(df.at[i, 'mentions'])
        for k in range(len(df.at[i, 'hashtags'])):
            try:
                df.at[i, 'hashtag'] = str(df.at[i, 'hashtag']) + ' ' + str(df.at[i, 'hashtags'][k]['text'])
            except:
                df.at[i, 'hashtag'] = str(df.at[i, 'hashtag'])
    # get rid of columns that we took everything we need from 
    df = df.drop(['user_mentions', 'hashtags'], 1)
    startdf = startdf.append(df)
    # not sure why id_ doesn't want to change unless reset but do it because it works and can't hurt
    id_ = None
    # get oldest id_ (lowest number) and subtract one so that that you don't reinclude it in the next search
    # reset id_ to be oldest
    id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1) 
    return startdf, id_

# %%
query_list1 = ['EXO', 'spacehotel', 'hubble', 'spaceprogram', 'thesolarsystem',
              'PerseveranceRover', 'SpaceExploration', 'lifeinspace',
              'voyagerstation', 'exoplanet', 'space']

# %%
query_list0 = ['ExoMars', 'HubbleGotchu', 'JWST', 'Mars', 'Mars2021',
              'PerseveranceRover', 'SpaceExploration', 'astrophotography',
              'perseverance', 'exoplanet', 'space']

# %%
query_list = ['SpaceExploration', 'perseverance', 'exoplanet', 'space', 'EXO', 'spacehotel',
               'hubble', 'spaceprogram', 'thesolarsystem', 'lifeinspace', 'voyagerstation']

# %%
# eventual goal is to use those loop to do all of our searches
end_item = datetime.datetime.now()

for item in query_list:
    #reset id_ to be most recent tweet for each item
    id_ = python_tweets.search(**{'q': 'RT', 'result_type': 'recent', 'count': 2})
    id_ = id_['statuses'][0]['id']
    # for each item, reset the start time to the end of the last item 
    start_time = end_item + datetime.timedelta(seconds=1)
    # set the end time to be 90 min after you start, gathering 50 tweets every 100 seconds for 2,700 tweets from each item in list
    end_item = end_item + datetime.timedelta(seconds=5401)
    #print start and end times so I know when the program will be finished and where it should be at 
    print(f'starting {item} time : {start_time.strftime("%H:%M:%S")}, ending time: {end_item.strftime("%H:%M:%S")}')
    #occassionally getting key/value errors of 0 that I cannot find the cause of, but do not affect anything in how our dataframe
    #is made, I just don't want them printing 
    with suppress(KeyError, ValueError):
        #initiate scheduler
        sch = Scheduler()
        #add our function and items, we're doing 50/10 seconds 
        sch.add_job(myfn, 'interval', (item, startdf), seconds=10, start_date=start_time, end_date=end_item)
        #start scheduler
        sch.start()
# Out:
# starting SpaceExploration time : 23:13:35, ending time: 00:43:35
# starting perseverance time : 00:43:36, ending time: 02:13:36
# starting exoplanet time : 02:13:37, ending time: 03:43:37
# starting space time : 03:43:38, ending time: 05:13:38
# starting EXO time : 05:13:39, ending time: 06:43:39
# starting spacehotel time : 06:43:40, ending time: 08:13:40
# starting hubble time : 08:13:41, ending time: 09:43:41
# starting spaceprogram time : 09:43:42, ending time: 11:13:42
# starting thesolarsystem time : 11:13:43, ending time: 12:43:43
# starting lifeinspace time : 12:43:44, ending time: 14:13:44
# starting voyagerstation time : 14:13:45, ending time: 15:43:45
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:14:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 1346, in getresponse
#     response.begin()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/retry.py", line 403, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/packages/six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 1346, in getresponse
#     response.begin()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 169, in _request
#     response = func(url, **requests_args)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 27, in myfn
#     for status in python_tweets.search(**query)['statuses']:
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/endpoints.py", line 293, in search
#     return self.get('search/tweets', params=params)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 278, in get
#     return self.request(endpoint, params=params, version=version)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 272, in request
#     api_call=url, json_encoded=json_encoded)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 171, in _request
#     raise TwythonError(str(e))
# twython.exceptions.TwythonError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:14:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:16:05 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:17:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:18:25 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:19:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:20:25 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 1346, in getresponse
#     response.begin()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/util/retry.py", line 403, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/packages/six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 1346, in getresponse
#     response.begin()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 169, in _request
#     response = func(url, **requests_args)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 27, in myfn
#     for status in python_tweets.search(**query)['statuses']:
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/endpoints.py", line 293, in search
#     return self.get('search/tweets', params=params)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 278, in get
#     return self.request(endpoint, params=params, version=version)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 272, in request
#     api_call=url, json_encoded=json_encoded)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/twython/api.py", line 171, in _request
#     raise TwythonError(str(e))
# twython.exceptions.TwythonError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:20:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:22:05 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:23:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:24:25 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:25:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:26:45 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:27:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:29:05 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:30:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:31:25 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:32:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:33:45 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-18 23:34:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
# ...
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:41:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:41:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:42:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:42:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:42:55 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:43:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:43:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-19 15:43:45 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-5-c6f0da348443>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds

# %%
len(startdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3feddd44e633> in <module>()
# ----> 1 len(startdf)
#
# NameError: name 'startdf' is not defined

# %%
startdf['hashtag'].value_counts().nlargest(50)
# Out:
#                                                                                             277415
#   Mars                                                                                       13151
#   EXO 엑소                                                                                      9602
#   WomenInScience SpaceExploration                                                             7099
#   Webb                                                                                        6206
#   PerseveranceRover                                                                           5682
#   BanglaChaayeBJPModel                                                                        4250
#   ExoMars                                                                                     3270
#   StanWorld SUHO 수호                                                                           3248
#   Mars Mars2021 PerseveranceRover perseverance archaeology Space ESA Aliens                   3096
#   Mars Mars2021 perseverancerover archaeology ESA Aliens alienuniverse NASA Area51            3078
#   GRAMMYs                                                                                     2950
#   Mars Mars2021                                                                               2623
#   DYK MarsEra USSR Mars6                                                                      2595
#   OTD space Mars                                                                              2323
#   OTD ExoMars                                                                                 2156
#   JWST                                                                                        2034
#   NASA Mars                                                                                   1890
#   Astrophotography                                                                            1880
#   Perseverancerover                                                                           1853
#   Flipkart gaming                                                                             1827
#   GalacticFederation Aliens                                                                   1785
#   Queen                                                                                       1737
#   SpaceFactFriday                                                                             1733
#   Mars Mars2021 PerseveranceRover                                                             1711
#   Perseverancerover Mars                                                                      1520
#   Mars Mars2021 PerseveranceRover perseverance                                                1510
#   SUHO StanWorld 수호                                                                           1428
#   Mars Mars2021 NASA socialmedia DataScience                                                  1316
#   Mars Mars2021 perseverancerover archaeology ESA Aliens alienuniverse NASA                   1291
#   KIP_GO                                                                                      1260
#   astrophotography                                                                            1221
#   NASAWebb                                                                                    1156
#   Mars ExoMars                                                                                1092
#   Cydonia                                                                                     1086
#   Perseverance                                                                                1056
#   Mars Mars2021 perseverancerover archaeology Military ESA Aliens alienuniverse NASA          1000
#   PerseveranceRover Mars                                                                       990
#   GalacticFederation Aliens PerseveranceRover                                                  952
#   Mars2020 Mars2021 PerseveranceRover                                                          905
#   Mars Mars2021 perseverancerover archaeology Space ESA Aliens alienuniverse NASA Area51       903
#   TheBoxPremiere CHANYEOLinTheBox 3월24일_찬열_더박스_개봉 찬열 엑소찬열                                      881
#   msg2mars mars2021 CountdownToMars                                                            755
#   NASA                                                                                         710
#   AuroraBorealis                                                                               684
#   engineers                                                                                    650
#   StPatricksDay                                                                                650
#   Navajo Mars                                                                                  606
#   LPSC2021                                                                                     595
#   comic MARS                                                                                   594
# Name: hashtag, dtype: int64

# %%
startdf.tail(20)
# Out:
#         favorite_count                      hashtag  \
# 30 NaN             0.0
# 31 NaN             0.0
# 32 NaN             0.0
# 33 NaN             0.0
# 34 NaN             0.0    Euro Russian ExoMars Mars
# 35 NaN             1.0    Euro Russian ExoMars Mars
# 36 NaN             0.0
# 37 NaN             0.0
# 38 NaN             0.0
# 39 NaN             0.0
# 40 NaN             0.0
# 41 NaN             0.0
# 42 NaN             0.0
# 43 NaN             0.0
# 44 NaN             0.0                      ExoMars
# 45 NaN             0.0
# 46 NaN             0.0
# 47 NaN             0.0
# 48 NaN             0.0
# 49 NaN             0.0
#
#                                    mentions       post_id  retweet_count  \
# 30             951062029 750389033579184129  1.368626e+18          119.0
# 31             951062029 750389033579184129  1.368623e+18          119.0
# 32             951062029 750389033579184129  1.368622e+18          119.0
# 33             951062029 750389033579184129  1.368619e+18          119.0
# 34                      1300418587669168129  1.368617e+18            1.0
# 35                                           1.368616e+18            1.0
# 36             951062029 750389033579184129  1.368615e+18          119.0
# 37             951062029 750389033579184129  1.368613e+18          119.0
# 38             951062029 750389033579184129  1.368613e+18          119.0
# 39             951062029 750389033579184129  1.368612e+18          119.0
# 40             951062029 750389033579184129  1.368610e+18          119.0
# 41             951062029 750389033579184129  1.368608e+18          119.0
# 42             951062029 750389033579184129  1.368607e+18          119.0
# 43    788990992338649088 787200579047043073  1.368606e+18            1.0
# 44                     905764884 4823641894  1.368606e+18           91.0
# 45             951062029 750389033579184129  1.368606e+18          119.0
# 46             951062029 750389033579184129  1.368605e+18          119.0
# 47             951062029 750389033579184129  1.368604e+18          119.0
# 48             951062029 750389033579184129  1.368603e+18          119.0
# 49             951062029 750389033579184129  1.368603e+18          119.0
#
#    symbols                                               text  \
# 30      []  RT @MichaelGalanin: A collection of spectacula...
# 31      []  RT @MichaelGalanin: A collection of spectacula...
# 32      []  RT @MichaelGalanin: A collection of spectacula...
# 33      []  RT @MichaelGalanin: A collection of spectacula...
# 34      []  RT @BrusselsMorning: The #Euro-#Russian #ExoMa...
# 35      []  The #Euro-#Russian #ExoMars mission passed sev...
# 36      []  RT @MichaelGalanin: A collection of spectacula...
# 37      []  RT @MichaelGalanin: A collection of spectacula...
# 38      []  RT @MichaelGalanin: A collection of spectacula...
# 39      []  RT @MichaelGalanin: A collection of spectacula...
# 40      []  RT @MichaelGalanin: A collection of spectacula...
# 41      []  RT @MichaelGalanin: A collection of spectacula...
# 42      []  RT @MichaelGalanin: A collection of spectacula...
# 43      []  RT @ExoMars_MOMA: Where will my rover @Exomars...
# 44      []  RT @ESA_ExoMars: #ExoMars 2022 update:\n🌀 Flig...
# 45      []  RT @MichaelGalanin: A collection of spectacula...
# 46      []  RT @MichaelGalanin: A collection of spectacula...
# 47      []  RT @MichaelGalanin: A collection of spectacula...
# 48      []  RT @MichaelGalanin: A collection of spectacula...
# 49      []  RT @MichaelGalanin: A collection of spectacula...
#
#                user       user_id
# 30      ameercherak  1.089510e+08
# 31           valy_m  1.038647e+18
# 32        Nayeem_ch  1.343894e+18
# 33          metoscm  2.994262e+09
# 34           4Tchat  1.129088e+18
# 35  BrusselsMorning  1.300419e+18
# 36  AbdelRhmn_Mhmud  1.036961e+18
# 37        farmer_tr  1.234548e+18
# 38         CORB_JST  1.349439e+18
# 39   matiascortez10  1.109739e+09
# 40          S3nshi3  1.281742e+18
# 41   camilla_casari  7.521551e+17
# 42          urdgart  2.018548e+08
# 43    ExoMars_NOMAD  4.860853e+09
# 44  peter1schueller  2.789230e+09
# 45      BakersRelay  1.013081e+18
# 46    JoeSinclair84  1.136387e+18
# 47        mmottab86  7.935391e+17
# 48  AugustineNumshi  1.163169e+18
# 49    gabriel194718  7.155600e+17
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:15:57 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:19:07 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:22:17 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:25:27 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:28:37 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:31:47 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:34:57 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:38:07 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:41:17 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds

# %%
startdf['text'][:25]
# Out:
# 0     RT @MichaelGalanin: A collection of spectacula...
# 1     RT @MichaelGalanin: A collection of spectacula...
# 2     RT @MichaelGalanin: A collection of spectacula...
# 3       ExoMars goes for a spin https://t.co/lsZkrvNmo6
# 4     RT @MichaelGalanin: A collection of spectacula...
# 5     RT @MichaelGalanin: A collection of spectacula...
# 6     RT @MichaelGalanin: A collection of spectacula...
# 7     RT @MichaelGalanin: A collection of spectacula...
# 8     RT @MichaelGalanin: A collection of spectacula...
# 9     RT @MichaelGalanin: A collection of spectacula...
# 10    New session: Perseverance ⟷ ExoMars TGO\nExpec...
# 11    RT @MichaelGalanin: A collection of spectacula...
# 12    RT @MichaelGalanin: A collection of spectacula...
# 13    ExoMars TGO downlinking 50.85 MB from Curiosit...
# 14    RT @MichaelGalanin: A collection of spectacula...
# 15    RT @MichaelGalanin: A collection of spectacula...
# 16    RT @MichaelGalanin: A collection of spectacula...
# 17    RT @MichaelGalanin: A collection of spectacula...
# 18    RT @MichaelGalanin: A collection of spectacula...
# 19    RT @MichaelGalanin: A collection of spectacula...
# 20    @Astro_Fonseca @ExoMars_CaSSIS @ESA_TGO Comple...
# 21    RT @MichaelGalanin: A collection of spectacula...
# 22    RT @mrn_status: ExoMars TGO downlinking 84.76 ...
# 23    RT @rocdocmars: Sent! Godspeed to my proposal ...
# 24    RT @MichaelGalanin: A collection of spectacula...
# Name: text, dtype: object
# /Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Job "myfn (trigger: interval[0:00:10], next run at: 2021-03-07 18:12:47 EST)" raised an exception
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4730, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas/_libs/index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 88, in pandas._libs.index.IndexEngine.get_value
#   File "pandas/_libs/index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 992, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 998, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-11-165b5279b83e>", line 60, in myfn
#     id_ = int(df['post_id'].sort_values(ascending=True).to_frame().reset_index()['post_id'][0] - 1)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py", line 1071, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/Users/tlipman/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 4736, in get_value
#     return libindex.get_value_box(s, key)
#   File "pandas/_libs/index.pyx", line 51, in pandas._libs.index.get_value_box
#   File "pandas/_libs/index.pyx", line 47, in pandas._libs.index.get_value_at
#   File "pandas/_libs/util.pxd", line 98, in pandas._libs.util.get_value_at
#   File "pandas/_libs/util.pxd", line 89, in pandas._libs.util.validate_indexer
# IndexError: index out of bounds

# %%
startdf = startdf.drop_duplicates(subset='text')

# %%
len(startdf)
# Out:
# 178828

# %%
# since every time we loop through it starts a new index, there are now multiple entries for each index, we need to fix this
# and the easiest way is to just reset the index once it finishes running 
startdf = startdf.drop_duplicates(subset='post_id')
startdf = startdf.reset_index()

# %%
# don't need these columns anymore
startdf = startdf.drop(['index', '', 'symbols'], 1)

# %%
# in order to add our strings for our hashtags and mentions together we had to make the entire column a string, sinlucding empty cells
# here we go through and replace empty cells with nan values so pandas will read them as being empty instead of a string
for i in range(len(startdf)):
    if startdf.at[i, 'mentions'] == ' ':
        startdf.at[i, 'mentions'] = np.nan
    else: 
        pass 
    if startdf.at[i, 'hashtag'] == ' ':
        startdf.at[i, 'hashtag'] = np.nan
    else: 
        pass

# %%
startdf.to_csv(r'name_of_the_file.csv')

# %%
# I scraped on:
# MARCH 08, 2021
# MARCH 10, 2021
# MARCH 18, 2021
# MARCH 19, 2021
# MARCH 20, 2021
# MARCH 21, 2021
# However, I accidentally did a git reset --hard HEAD@{1} and unwrote the 6 days of scraping files created.
# Luckily, I have the master file containing the concatenation of all of the individual files put together.
